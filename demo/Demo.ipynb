# %%
from pathlib import Path
from IPython import get_ipython
from ipython_pathlib_completer import enable_pathlib_completer, enable_debug_log

# enable_debug_log("./debug.log")

enable_pathlib_completer()
parent = Path("../")

# %%
# parent / <TAB>
parent / 

# parent / tests / <TAB>
parent / "tests" / 

# Path("../") / <TAB>
Path("../") /
